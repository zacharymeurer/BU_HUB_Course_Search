# %%
import numpy as np
import requests
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt
import re

pd.set_option('display.max_rows', 40)
pd.set_option('display.max_columns', 30)
pd.set_option('display.width', 100)

# %%
# Data Scraping from course registration site
College, Dept, Number = 'CDS', 'DS', 320
URL = f"""https://www.bu.edu/link/bin/uiscgi_studentlink/1698859245?ModuleName=univschr.pl
          &SearchOptionDesc=Class+Number
          &SearchOptionCd=S
          &KeySem=20244
          &ViewSem=Spring+2024
          &College={College}
          &Dept={Dept}
          &Course={Number}
          &Section="""
URL = re.sub("\s", "", URL)

r = requests.get(URL)
  
soup = BeautifulSoup(r.content, 'lxml')

col_names = []
data = []
table = soup.find_all('table', border='', cellpadding='')


rows = table[1].find_all('tr')
for row in rows:
    cols = row.find_all('td')
    cols = [ele.text.strip() for ele in cols]
    data.append([ele for ele in cols if ele]) # Get rid of empty values

pd.DataFrame(data, columns=["Course","Title/Instructor","Credits","Type","Open Seats","Bld","Room","Day","Start",
                            "Stop","Notes"])
# Out:
#                                                                                                    Course  \
# 0                                                                                                    None
# 1   Students registering for CDS DS320 must register for two  sections: a Lec section, and a Dis section.
# 2   Students registering for CDS DS320 must register for two  sections: a Lec section, and a Dis section.
# 3                                                                                            CDS DS320 A1
# 4                                                                                            CDS DS320 A2
# 5                                                                                            CDS DS320 A3
# 6    Students registering for CDS DS340 must register for two sections: a Lec section, and a Dis section.
# 7    Students registering for CDS DS340 must register for two sections: a Lec section, and a Dis section.
# 8                                                                                            CDS DS340 A1
# 9                                                                                            CDS DS340 A2
# 10                                                                                           CDS DS340 A3
# 11                                                                                           CDS DS340 A4
# 12   Students registering for CDS DS380 must register for two sections: a Lec section, and a Dis section.
# 13   Students registering for CDS DS380 must register for two sections: a Lec section, and a Dis section.
# 14                                                                                           CDS DS380 A1
# 15                                                                                           CDS DS380 B1
# 16                                                                                           CDS DS380 B2
# 17   Students registering for CDS DS453 must register for two sections: a Lec section, and a Dis section.
# 18   Students registering for CDS DS453 must register for two sections: a Lec section, and a Dis section.
# 19                                                                                           CDS DS453 A1
# 20                                                                                           CDS DS453 B1
# 21                                                                                           CDS DS453 B2
# 22                                                                                           CDS DS482 A1
# 23                                                                                           CDS DS488 A1
# 24                                                                                           CDS DS490 A1
# 25                                                                                           CDS DS490 W1
# 26                                                                                           CDS DS519 A1
# 27                                                                                           CDS DS549 A1
# 28   Students registering for CDS DS563 must register for two sections: a Lec section, and a Dis section.
# 29   Students registering for CDS DS563 must register for two sections: a Lec section, and a Dis section.
# 30                                                                                           CDS DS563 A1
#
#                                                                                          Title/Instructor  \
# 0                                                                                                    None
# 1   Students registering for CDS DS320 must register for two  sections: a Lec section, and a Dis section.
# 2                                                                                                    None
# 3                                                                                    Algs Data SciGoldner
# 4                                                                                    Algs Data SciGoldner
# 5                                                                                    Algs Data SciGoldner
# 6    Students registering for CDS DS340 must register for two sections: a Lec section, and a Dis section.
# 7                                                                                                    None
# 8                                                                                       Intro Ml & AiGold
# 9                                                                                       Intro Ml & AiGold
# 10                                                                                      Intro Ml & AiGold
# 11                                                                                      Intro Ml & AiGold
# 12   Students registering for CDS DS380 must register for two sections: a Lec section, and a Dis section.
# 13                                                                                                   None
# 14                                                                                 Data Ethics SocWildman
# 15                                                                                 Data Ethics SocWildman
# 16                                                                                 Data Ethics SocWildman
# 17   Students registering for CDS DS453 must register for two sections: a Lec section, and a Dis section.
# 18                                                                                                   None
# 19                                                                                     Crypto for DsVaria
# 20                                                                                     Crypto for DsVaria
# 21                                                                                     Crypto for DsVaria
# 22                                                                                     Ai LAW EthicsocHod
# 23                                                                                     Spark Ux PracStaff
# 24                                                                                    Directed StudyStaff
# 25                                                                                    Directed StudyStaff
# 26                                                                                     Spark Se PracMishr
# 27                                                                                    Spark Ml PracGardos
# 28   Students registering for CDS DS563 must register for two sections: a Lec section, and a Dis section.
# 29                                                                                                   None
# 30                                                                                    Taming Big DataOnak
#
#    Credits            Type Open Seats    Bld     Room         Day  \
# 0     None            None       None   None     None        None
# 1     None            None       None   None     None        None
# 2     None            None       None   None     None        None
# 3      4.0         Lecture          2    EPC      209     Tue,Thu
# 4      0.0      Discussion          0    FLR      121         Wed
# 5      0.0      Discussion          0    FLR      121         Wed
# 6     None            None       None   None     None        None
# 7     None            None       None   None     None        None
# 8      4.0         Lecture         31    EPC      207     Tue,Thu
# 9      0.0      Discussion          6    CDS      164         Thu
# 10     0.0      Discussion         12    CDS      164         Thu
# 11     0.0      Discussion          0    CDS      164         Thu
# 12    None            None       None   None     None        None
# 13    None            None       None   None     None        None
# 14     4.0         Lecture         14    KCB      106     Tue,Thu
# 15     0.0      Discussion          2    CDS      164         Wed
# 16     0.0      Discussion          3    CDS      164         Wed
# 17    None            None       None   None     None        None
# 18    None            None       None   None     None        None
# 19     4.0         Lecture          0    EPC      204     Tue,Thu
# 20     0.0      Discussion         11    CDS      164         Mon
# 21     0.0      Discussion          4    CDS      164         Mon
# 22     4.0     Independent         15     NO     ROOM    Arranged
# 23     4.0     Independent          1  COMNO  109ROOM  Tue,ThuWed
# 24     var  Directed Study          2     NO     ROOM    Arranged
# 25     var  Directed Study          2     NO     ROOM    Arranged
# 26     4.0     Independent          5  CDSNO  164ROOM  Tue,ThuWed
# 27     4.0     Independent          7  CDSNO  164ROOM  Tue,ThuWed
# 28    None            None       None   None     None        None
# 29    None            None       None   None     None        None
# 30     4.0         Lecture          0    CAS      220     Tue,Thu
#
#                                Start           Stop                          Notes
# 0                               None           None                           None
# 1                               None           None                           None
# 2                               None           None                           None
# 3                             2:00pm         3:15pm            Permission Required
# 4                             3:35pm         4:25pm  Permission RequiredClass Full
# 5                             4:40pm         5:30pm  Permission RequiredClass Full
# 6                               None           None                           None
# 7                               None           None                           None
# 8                             2:00pm         3:15pm            Permission Required
# 9                             9:30am        10:45am            Permission Required
# 10                           11:15am        12:05pm            Permission Required
# 11                           12:30pm         1:45pm  Permission RequiredClass Full
# 12                              None           None                           None
# 13                              None           None                           None
# 14                           11:00am        12:15pm            Permission Required
# 15                           12:20pm         1:10pm            Permission Required
# 16                            1:25pm         2:15pm            Permission Required
# 17                              None           None                           None
# 18                              None           None                           None
# 19                            9:30am        10:45am      Mts w/CDS DS653Class Full
# 20                            9:05am         9:55am                Mts w/CDS DS653
# 21                           11:15am        12:05pm                Mts w/CDS DS653
# 22  Mts w/CDS DS682WebReg Restricted           None                           None
# 23                     5:00pm 6:30pm  6:15pm 7:30pm                Mts w/CDS DS688
# 24                 WebReg Restricted           None                           None
# 25                 WebReg Restricted           None                           None
# 26                     5:00pm 6:30pm  6:15pm 7:30pm                Mts w/CAS CS519
# 27                     2:00pm 6:30pm  3:15pm 7:30pm                Mts w/CAS CS549
# 28                              None           None                           None
# 29                              None           None                           None
# 30                            3:30pm         4:45pm      Mts w/CAS CS543Class Full

# %%
# Functions

def scrape_course_website(course_data, hub_data, url):
    r = requests.get(url)

    soup = BeautifulSoup(r.content, "html.parser")

    for course in soup.find_all('div', class_='cf-course-card'):
        
        # course_data
        course_id = course.find('span', class_='cf-course-id')
        course_college, course_dept, course_number = course_id.find_all('span')
        course_name = course.find('h3', class_='bu_collapsible')
        course_details = course.find('p', class_='meta cf-course-info')
        course_credits, course_availability, course_prereqs = course_details.find_all('span')
        course_desc = course.find('p', class_='cf-course-description')
        course_info = [course_id, course_college, course_dept, course_number, course_name, course_credits, 
                       course_availability, course_prereqs, course_desc]
        course_data.append([ele.get_text() for ele in course_info])
        
        # hub_data
        course_hubs = course.find('ul', class_='cf-hub-offerings')
        for course_hub in course_hubs.find_all('li'):
            hub_info = [course_id, course_hub]
            hub_data.append([ele.get_text() for ele in hub_info])
            
def courses_with_hubs(how_many, needed_hubs, display_all=False):    
    for idx, _ in enumerate(needed_hubs):
        for key, value in hub_nickname_dict.items():
            needed_hubs[idx] = needed_hubs[idx].replace(key, value)
    
    # Exceptions
    if type(how_many) != int:
        if type(how_many) != float:
            raise TypeError("first parameter should be an integer")
        else:
            how_many = int(how_many)
    elif how_many < 1:
        raise Exception("first parameter should be a positive number")
    elif how_many > np.unique(hub_df["Course_id"], return_counts=True)[1].max():
        raise Exception("There are no classes with " + str(how_many) + " or more hubs")
    
    eligible_courses = []
    for Course_id in course_df["Course_id"]:
        needed_hubs_counter = 0
        Course_hubs = ""
        for hub_abbr in hub_df[hub_df["Course_id"] == Course_id]["Hub_abbr"]:
            Course_hubs += hub_abbr + " "
            if hub_abbr in needed_hubs:
                needed_hubs_counter += 1
        if needed_hubs_counter >= how_many:
            
            eligible_courses.append([Course_id,Course_hubs])
    eligible_courses = np.array(eligible_courses)
    
    if display_all:
        pd.set_option('display.max_rows', len(eligible_courses))
    else:
        pd.set_option('display.max_rows', 40)
    
    if eligible_courses.size == 0: # In case there are no eligible courses
        raise ValueError("No classes matching this criteria")
    
    selected_df = course_df.loc[course_df['Course_id'].isin(eligible_courses[:,0])].copy()
    selected_df["Hubs"] = eligible_courses[:,1]
    selected_df = selected_df.sort_values(by=['Course_id'])
    selected_df = selected_df.reset_index(drop=True)
    return selected_df

#def search_by_course_id(Course_id)

# %%
# Creating tables

course_data = []
hub_data = []
URLs = ['https://www.bu.edu/hub/hub-courses/philosophical-aesthetic-and-historical-interpretation/', 
        'https://www.bu.edu/hub/hub-courses/scientific-and-social-inquiry/', 
        'https://www.bu.edu/hub/hub-courses/quantitative-reasoning/', 
        'https://www.bu.edu/hub/hub-courses/diversity-civic-engagement-and-global-citizenship/', 
        'https://www.bu.edu/hub/hub-courses/communication/', 
        'https://www.bu.edu/hub/hub-courses/intellectual-toolkit/']

for url in URLs:
    scrape_course_website(course_data, hub_data, url)

max_description_len = max(list(map(lambda x: len(x), np.array(course_data)[:,8])))
pd.set_option('display.max_colwidth', max_description_len)

course_df = pd.DataFrame(course_data, columns=["Course_id", "College", "Department", "Number", "Title", "Credits", 
                                               "Availability", "Prerequisites", "Description"])
course_df = course_df.drop_duplicates(ignore_index=True)
hub_df = pd.DataFrame(hub_data, columns=["Course_id","Hub"])
hub_df = hub_df.drop_duplicates(ignore_index=True)

hub_nickname_dict = {
    "PLM": "Philosophical Inquiry and Life's Meanings",
    "AEX": "Aesthetic Exploration",
    "HCO": "Historical Consciousness",
    "SI1": "Scientific Inquiry I",
    "SI2": "Scientific Inquiry II",
    "SO1": "Social Inquiry I",
    "SO2": "Social Inquiry II",
    "QR1": "Quantitative Reasoning I",
    "QR2": "Quantitative Reasoning II",
    "IIC": "The Individual in Community",
    "GCI": "Global Citizenship and Intercultural Literacy",
    "ETR": "Ethical Reasoning",
    "FYW": "First-Year Writing Seminar",
    "WRI": "Writing, Research, and Inquiry",
    "WIN": "Writing-Intensive Course",
    "OSC": "Oral and/or Signed Communication",
    "DME": "Digital/Multimedia Expression",
    "CRT": "Critical Thinking",
    "RIL": "Research and Information Literacy",
    "TWC": "Teamwork/Collaboration",
    "CRI": "Creativity/Innovation" 
}

hub_nickname_dict = {v: k for k, v in hub_nickname_dict.items()}

hub_df['Hub_abbr'] = hub_df.replace({'Hub': hub_nickname_dict}).Hub

# %%
# My applications

zachs_needed_hubs_abbr = ["PLM", "AEX", "IIC", "GCI", "WRI", "WIN", "OSC", "RIL", "CRI"] # What Hubs I need to graduate
        
courses_with_hubs(3, zachs_needed_hubs_abbr, True)
# Out:
#       Course_id College Department Number  \
# 0    CAS AA 210     CAS         AA    210
# 1    CAS AA 404     CAS         AA    404
# 2    CAS AA 411     CAS         AA    411
# 3    CAS AA 519     CAS         AA    519
# 4    CAS AH 220     CAS         AH    220
# 5    CAS AH 313     CAS         AH    313
# 6    CAS AH 327     CAS         AH    327
# 7    CAS AH 364     CAS         AH    364
# 8    CAS AH 399     CAS         AH    399
# 9    CAS AH 495     CAS         AH    495
# 10   CAS AH 533     CAS         AH    533
# 11   CAS AM 220     CAS         AM    220
# 12   CAS AN 308     CAS         AN    308
# 13   CAS AN 312     CAS         AN    312
# 14   CAS AR 533     CAS         AR    533
# 15   CAS AS 441     CAS         AS    441
# 16   CAS BI 225     CAS         BI    225
# 17   CAS BI 509     CAS         BI    509
# 18   CAS CC 102     CAS         CC    102
# 19   CAS CC 201     CAS         CC    201
# 20   CAS CG 357     CAS         CG    357
# 21   CAS CH 212     CAS         CH    212
# 22   CAS CI 270     CAS         CI    270
# 23   CAS CI 325     CAS         CI    325
# 24   CAS CI 378     CAS         CI    378
# 25   CAS CI 482     CAS         CI    482
# 26   CAS CI 512     CAS         CI    512
# 27   CAS CI 551     CAS         CI    551
# 28   CAS CL 227     CAS         CL    227
# 29   CAS CL 302     CAS         CL    302
# 30   CAS CL 305     CAS         CL    305
# 31   CAS CL 310     CAS         CL    310
# 32   CAS CL 313     CAS         CL    313
# 33   CAS CL 406     CAS         CL    406
# 34   CAS EN 121     CAS         EN    121
# 35   CAS EN 145     CAS         EN    145
# 36   CAS EN 213     CAS         EN    213
# 37   CAS EN 220     CAS         EN    220
# 38   CAS EN 306     CAS         EN    306
# 39   CAS EN 356     CAS         EN    356
# 40   CAS EN 369     CAS         EN    369
# 41   CAS EN 379     CAS         EN    379
# 42   CAS EN 383     CAS         EN    383
# 43   CAS EN 398     CAS         EN    398
# 44   CAS EN 403     CAS         EN    403
# 45   CAS EN 471     CAS         EN    471
# 46   CAS EN 493     CAS         EN    493
# 47   CAS EN 510     CAS         EN    510
# 48   CAS EN 517     CAS         EN    517
# 49   CAS EN 519     CAS         EN    519
# 50   CAS EN 520     CAS         EN    520
# 51   CAS EN 564     CAS         EN    564
# 52   CAS EN 569     CAS         EN    569
# 53   CAS ID 116     CAS         ID    116
# 54   CAS IR 517     CAS         IR    517
# 55   CAS IR 533     CAS         IR    533
# 56   CAS JS 121     CAS         JS    121
# 57   CAS JS 282     CAS         JS    282
# 58   CAS JS 283     CAS         JS    283
# 59   CAS JS 348     CAS         JS    348
# 60   CAS JS 383     CAS         JS    383
# 61   CAS LC 261     CAS         LC    261
# 62   CAS LC 416     CAS         LC    416
# 63   CAS LC 451     CAS         LC    451
# 64   CAS LF 323     CAS         LF    323
# 65   CAS LF 343     CAS         LF    343
# 66   CAS LF 350     CAS         LF    350
# 67   CAS LF 351     CAS         LF    351
# 68   CAS LF 441     CAS         LF    441
# 69   CAS LF 455     CAS         LF    455
# 70   CAS LF 462     CAS         LF    462
# 71   CAS LF 464     CAS         LF    464
# 72   CAS LF 483     CAS         LF    483
# 73   CAS LG 308     CAS         LG    308
# 74   CAS LG 350     CAS         LG    350
# 75   CAS LH 250     CAS         LH    250
# 76   CAS LH 283     CAS         LH    283
# 77   CAS LH 312     CAS         LH    312
# 78   CAS LI 303     CAS         LI    303
# 79   CAS LI 312     CAS         LI    312
# 80   CAS LI 354     CAS         LI    354
# 81   CAS LI 355     CAS         LI    355
# 82   CAS LJ 261     CAS         LJ    261
# 83   CAS LJ 360     CAS         LJ    360
# 84   CAS LJ 386     CAS         LJ    386
# 85   CAS LJ 460     CAS         LJ    460
# 86   CAS LK 261     CAS         LK    261
# 87   CAS LR 282     CAS         LR    282
# 88   CAS LR 457     CAS         LR    457
# 89   CAS LS 309     CAS         LS    309
# 90   CAS LS 311     CAS         LS    311
# 91   CAS LS 410     CAS         LS    410
# 92   CAS LS 449     CAS         LS    449
# 93   CAS LS 456     CAS         LS    456
# 94   CAS LS 477     CAS         LS    477
# 95   CAS LX 367     CAS         LX    367
# 96   CAS LY 350     CAS         LY    350
# 97   CAS LY 411     CAS         LY    411
# 98   CAS LY 441     CAS         LY    441
# 99   CAS LZ 315     CAS         LZ    315
# 100  CAS MS 502     CAS         MS    502
# 101  CAS PH 245     CAS         PH    245
# 102  CAS PH 426     CAS         PH    426
# 103  CAS PH 495     CAS         PH    495
# 104  CAS PH 496     CAS         PH    496
# 105  CAS PO 519     CAS         PO    519
# 106  CAS PO 523     CAS         PO    523
# 107  CAS PO 547     CAS         PO    547
# 108  CAS PY 581     CAS         PY    581
# 109  CAS RN 100     CAS         RN    100
# 110  CAS RN 104     CAS         RN    104
# 111  CAS RN 106     CAS         RN    106
# 112  CAS RN 245     CAS         RN    245
# 113  CAS RN 338     CAS         RN    338
# 114  CAS RN 400     CAS         RN    400
# 115  CAS RN 427     CAS         RN    427
# 116  CAS RN 452     CAS         RN    452
# 117  CAS SO 404     CAS         SO    404
# 118  CAS SO 442     CAS         SO    442
# 119  CAS TL 541     CAS         TL    541
# 120  CAS WR 151     CAS         WR    151
# 121  CAS WR 153     CAS         WR    153
# 122  CAS WR 320     CAS         WR    320
# 123  CAS XL 222     CAS         XL    222
# 124  CAS XL 223     CAS         XL    223
# 125  CAS XL 224     CAS         XL    224
# 126  CAS XL 225     CAS         XL    225
# 127  CAS XL 261     CAS         XL    261
# 128  CAS XL 313     CAS         XL    313
# 129  CAS XL 342     CAS         XL    342
# 130  CAS XL 343     CAS         XL    343
# 131  CAS XL 344     CAS         XL    344
# 132  CAS XL 381     CAS         XL    381
# 133  CAS XL 441     CAS         XL    441
# 134  CAS XL 451     CAS         XL    451
# 135  CAS XL 479     CAS         XL    479
# 136  CAS XL 541     CAS         XL    541
# 137  CFA AR 121     CFA         AR    121
# 138  CFA AR 243     CFA         AR    243
# 139  CFA AR 369     CFA         AR    369
# 140  CFA AR 415     CFA         AR    415
# 141  CFA AR 425     CFA         AR    425
# 142  CFA AR 470     CFA         AR    470
# 143  CFA AR 501     CFA         AR    501
# 144  CFA AR 770     CFA         AR    770
# 145  CFA ME 377     CFA         ME    377
# 146  CFA MH 404     CFA         MH    404
# 147  CFA MH 411     CFA         MH    411
# 148  CFA MH 413     CFA         MH    413
# 149  CFA MH 436     CFA         MH    436
# 150  CFA MP 332     CFA         MP    332
# 151  CGS IN 306     CGS         IN    306
# 152  CGS RH 103     CGS         RH    103
# 153  CGS SS 201     CGS         SS    201
# 154  COM CO 201     COM         CO    201
# 155  COM JO 210     COM         JO    210
# 156  COM JO 519     COM         JO    519
# 157  COM JO 539     COM         JO    539
# 158  ENG BE 466     ENG         BE    466
# 159  ENG ME 461     ENG         ME    461
# 160  HUB SA 300     HUB         SA    300
# 161  HUB XC 410     HUB         XC    410
# 162  HUB XC 433     HUB         XC    433
# 163  HUB XC 475     HUB         XC    475
# 164  KHC AH 103     KHC         AH    103
# 165  KHC EN 103     KHC         EN    103
# 166  KHC EN 104     KHC         EN    104
# 167  KHC FT 103     KHC         FT    103
# 168  KHC RH 101     KHC         RH    101
# 169  KHC VA 104     KHC         VA    104
# 170  KHC XL 101     KHC         XL    101
# 171  QST ES 275     QST         ES    275
# 172  QST SI 422     QST         SI    422
# 173  QST SM 275     QST         SM    275
# 174  SAR HS 408     SAR         HS    408
# 175  SED ED 200     SED         ED    200
#
#                                                                                                                     Title  \
# 0                                                                                                     American Minstrelsy
# 1                                                                                        Seminar on Sociology of Families
# 2                                                                          Race, Memory, and Diaspora in US Popular Music
# 3                                                                                        Inequality and American Politics
# 4                                                                                            Islamic Art and Architecture
# 5                                                         Imperial Reflections: Early Modern Islamic Art and Architecture
# 6                                                                                                           Arts of China
# 7                                                                            Art and Architecture in Madrid, 1561 - Today
# 8                                                                            History and Theory of Landscape Architecture
# 9                                                                                          Seminar: Twentieth Century Art
# 10                                                                                    Seminar: Greek Art and Architecture
# 11                                                                                 Native American and Indigenous Studies
# 12                                                       Food in Place(s): Identity, Location, and the Cultures of Taste
# 13                                                                                  Peoples and Cultures of Africa (area)
# 14                                                                                    Seminar: Greek Art and Architecture
# 15                                                                                                Observational Astronomy
# 16                                                                                                     Behavioral Biology
# 17                                                                                                 Metapopulation Ecology
# 18                                                           Core Humanities 2: The Way: Antiquity and the Medieval World
# 19                                                         Core Humanities III: Renaissance, Rediscovery, and Reformation
# 20                                                                                          Modern Greek Culture and Film
# 21                                                                                          Intensive Organic Chemistry 2
# 22                                                                  Israeli Culture through Film (in English translation)
# 23                                                                 Tradition and Modernity in Iranian Film and Literature
# 24                                                                                          Modern Greek Culture and Film
# 25                                                                                      Cinema-Monde: Mapping French Film
# 26                                                                                                  Film and Media Theory
# 27                                                                                           Studies in Auteur Filmmaking
# 28                                                                                             Rome and the Chinese World
# 29                                                                                                    The Age of Augustus
# 30                                                                                                         Topics in Myth
# 31                                                                           The Classical Tradition in Modern Literature
# 32                                                                                            The "Odyssey" and "Ulysses"
# 33                                                                              Advanced Topics in Classical Civilization
# 34                                                                                               Reading World Literature
# 35                                                                                            Introduction to Performance
# 36                                                                                            The "Odyssey" and "Ulysses"
# 37                                                                                                  Seminar in Literature
# 38                                                                                            Introduction to Playwriting
# 39                                                                                  Drama and Performance, 1945 - Present
# 40                                                                                        Haruki Murakami and His Sources
# 41                                                                                                        American Poetry
# 42                                                                                                  Australian Literature
# 43                                                                                                    Global Shakespeares
# 44                                                                                            Advanced Writing of Poetry
# 45                                                                        Critical Studies in American Literary Movements
# 46                                                                            Critical Studies in Literature and The Arts
# 47                                                                                  Playwriting 1: Writing of Short Plays
# 48                                                               Drama in Theory and Practice 1: Structure and the Script
# 49                                                    Drama in Theory and Practice 2: Experiments with Character and Form
# 50                                                             Drama in Theory and Practice 3: Adaptation and the Theatre
# 51                                                                                           Studies in Auteur Filmmaking
# 52                                                                                                  Film and Media Theory
# 53                                                                              Africa Today: The Beat of Popular Culture
# 54                                                                            Balkan Politics and International Relations
# 55                                                         Contentious Politics and the Arab Uprisings in the Middle East
# 56                                                                                       Judaism, Christianity, and Islam
# 57                                                                          Sixth-Semester Hebrew: Food Culture in Israel
# 58                                                                  Israeli Culture through Film (in English translation)
# 59                                                              Philosophy and Mysticism: Jewish and Islamic Perspectives
# 60                                                                  Israeli Culture through Film (in English translation)
# 61                                                                                                 S24: Chinese Religion
# 62                                                                                  Chinese through Literary Masterpieces
# 63    Visual Politics: Propaganda Art, Literature, and "Model Films" during the   Chinese Cultural   Revolution 1966-1976
# 64                                                                                             Creative Writing in French
# 65                                                                                      Literary Representations of Paris
# 66                                                                                                 Reading the French Way
# 67                                                                                       Introduction to the French Novel
# 68                                                                     Topics in Urban Imgainaries in Literature and Film
# 69                                                                        Studies in Nineteenth-Century French Literature
# 70                                                                                      Cinema-Monde: Mapping French Film
# 71                                                                                                          Author/Auteur
# 72                                                          Topics in Literature and Politics: Revolution, Power, Culture
# 73                                                                              Food Culture in German-Speaking Countries
# 74                                                                                      Introduction to German Literature
# 75                                                          Masterpieces of Modern Hebrew Literature (taught in English)
# 76                                                                       Israeli Culture through Film (taught in English)
# 77                                                                          Sixth-Semester Hebrew: Food Culture in Israel
# 78                                                                           Exploring Padua: culture, language, and life
# 79                                                                                            Italian for the Professions
# 80                                                                                        Contemporary Italian Literature
# 81                                                                                             Italian Migrant Literature
# 82                                                                                             Rome and the Chinese World
# 83                                                                                                                  Haiku
# 84                                                                           Japanese Translation/Interpretation Workshop
# 85                                                                                        Haruki Murakami and His Sources
# 86                                                                                             Rome and the Chinese World
# 87                                               Russian Prose Classics of the Twentieth Century (in English translation)
# 88                                                                               Advanced Russian Language and Literature
# 89                                                                               Spanish for Heritage and Native Speakers
# 90                                                              Spanish Through Performance: The Theater of Everyday Life
# 91                                                                              Religion and Literature in Medieval Spain
# 92                                                                   Contemporary Spanish Novel: From ?La Movida? to 15-M
# 93                                                                           Medieval and Early Modern Iberian Literature
# 94                                                                                            Contemporary Spanish Cinema
# 95                                                                                 Indigenous Languages of Latin America
# 96                                                                                      Introduction to Arabic Literature
# 97                                                                              Arab Society through Hip Hop and Cartoons
# 98                                                                          1001 Nights in the World Literary Imagination
# 99                                                                 Tradition and Modernity in Iranian Film and Literature
# 100                                             Seven-Year Liberal Arts/Medical Education Program Hub Sequence Semester 2
# 101                                                                                        The Quest for God and the Good
# 102                                                                                                         Phenomenology
# 103                                                             Philosophy and Mysticism: Jewish and Islamic Perspectives
# 104                                                                                           Topics in Religious Thought
# 105                                                                                      Inequality and American Politics
# 106                                                                                  Infrastructure and Land Use Politics
# 107                                                                                                  US Social Movements
# 108                                                                                                   Advanced Laboratory
# 109                                                                                              Introduction to Religion
# 110                                                                                      Judaism, Christianity, and Islam
# 111                                                                                                 Death and Immortality
# 112                                                                                        The Quest for God and the Good
# 113                                                             Philosophy and Mysticism: Jewish and Islamic Perspectives
# 114                                                                                                      Writing Religion
# 115                                                                                           Topics in American Religion
# 116                                                                                           Topics in Religious Thought
# 117                                                                                      Seminar on Sociology of Families
# 118                                                                             Seminar: Urban Inequality in the Americas
# 119                                                                                                     Translation Today
# 120                                                       Writing, Research, & Inquiry with Oral and/or Signed Expression
# 121                                                               Writing, Research, & Inquiry with Creativity/Innovation
# 122                                                                                              Community-based Writing
# 123                                                                                   Introduction to Western Literatures
# 124                                                                            Introduction to Middle Eastern Literatures
# 125                                                                                Introduction to East Asian Literatures
# 126                                                                               Introduction to South Asian Literatures
# 127                                                                                            Rome and the Chinese World
# 128                                                                                           The "Odyssey" and "Ulysses"
# 129                                                                                   Travel Writing and the Muslim World
# 130                                                                                       Alexander the Great in the East
# 131                                                                                                   Global Shakespeares
# 132                                                              Topics in Gender and Literature (in English translation)
# 133                                                                         1001 Nights in the World Literary Imagination
# 134     Visual Politics: Propaganda Art, Literature, and "Model Films" during the  Chinese Cultural  Revolution 1966-1976
# 135                                                                                                    WLL Senior Seminar
# 136                                                                                                     Translation Today
# 137                                                                                                 Foundation Sculpture
# 138                                                                                                         Photography 1
# 139                                                                                 Art, Community, and Social Engagement
# 140                                                                                                         Photography 1
# 141                                                                       The Artist and the Book (4 credits Spring term)
# 142                                                                                                            Ceramics 1
# 143                                                                                                               Drw Ven
# 144                                                                                                            Ceramics 1
# 145              Arts Engagement as Active Hope: Attuning, Reflecting, and Writing Our Way Towards  a Sustainable Future
# 146                                                                              Approaches to Sacred Music East and West
# 147                                                                        Race, Memory, and Diaspora in US Popular Music
# 148                                                                                                            Restagings
# 149                                                                                                       Musical Culture
# 150                                                                                                     Song Literature 2
# 151                                                                                                  Shakespeare's Ethics
# 152                                                          Rhetorical Practices from the Ancient World to Enlightenment
# 153                                                        Radicals, Rebels, and Revolutionaries: Agents of Global Change
# 154                                                                                 Introduction to Communication Writing
# 155                                                                                                    Reporting in Depth
# 156                                                                                                       Narrative Radio
# 157                                                                                           Global Health Storytelling
# 158                                                                                 Biomedical Engineering Senior Project
# 159                                                                                                      Senior Design II
# 160                                                                                                            Kyotolaang
# 161                                                                             BU Cross-College Challenge Projects (WIN)
# 162                                                                             BU Cross-College Challenge Projects (OSC)
# 163                                                                                             Spark! Innovation Program
# 164                                                                                                      Experimental Art
# 165                                                                                                    Poetry as Activism
# 166                                                              Writing Lives: The Craft and Forms of Literary Biography
# 167                                                                       Screenwriting: Doing Justice Through Adaptation
# 168                                                   Serious Comics: Graphic Narrative and the Representation of History
# 169                                                                                   More than a Face: What Masks Reveal
# 170                                                                    Global Shakespeares: Text, Culture, Appropriation
# 171                                                                                             Management Communications
# 172                                                                          Strategy, Innovation, and Global Competition
# 173                                                                                             Management Communications
# 174                                                                            Mediterranean Diet: Food, Culture & Health
# 175                                                                               Introduction to Justice-Based Education
#
#         Credits Availability  \
# 0    4 credits.     2nd sem.
# 1    4 credits.  Either sem.
# 2    4 credits.  Either sem.
# 3    4 credits.  Either sem.
# 4    4 credits.  Either sem.
# 5    4 credits.
# 6    4 credits.  Either sem.
# 7    4 credits.
# 8    4 credits.
# 9    4 credits.  Either sem.
# 10   4 credits.
# 11   4 credits.  Either sem.
# 12   4 credits.
# 13   4 credits.  Either sem.
# 14   4 credits.  Either sem.
# 15   4 credits.     2nd sem.
# 16   4 credits.
# 17   4 credits.
# 18   4 credits.     2nd sem.
# 19   4 credits.     1st sem.
# 20   4 credits.
# 21   4 credits.     2nd sem.
# 22   4 credits.
# 23   4 credits.  Either sem.
# 24   4 credits.
# 25   4 credits.  Either sem.
# 26   4 credits.  Either sem.
# 27   4 credits.
# 28   4 credits.     2nd sem.
# 29   4 credits.
# 30   4 credits.  Either sem.
# 31   4 credits.     1st sem.
# 32   4 credits.
# 33   4 credits.  Either sem.
# 34   4 credits.  Either sem.
# 35   4 credits.
# 36   4 credits.
# 37   4 credits.  Either sem.
# 38   4 credits.  Either sem.
# 39   4 credits.  Either sem.
# 40   4 credits.
# 41   4 credits.  Either sem.
# 42   4 credits.  Either sem.
# 43   4 credits.
# 44   4 credits.     2nd sem.
# 45   4 credits.  Either sem.
# 46   4 credits.  Either sem.
# 47   4 credits.     1st sem.
# 48   4 credits.     1st sem.
# 49   4 credits.     2nd sem.
# 50   4 credits.     2nd sem.
# 51   4 credits.  Either sem.
# 52   4 credits.  Either sem.
# 53   4 credits.  Either sem.
# 54   4 credits.
# 55   4 credits.  Either sem.
# 56   4 credits.  Either sem.
# 57   4 credits.     1st sem.
# 58   4 credits.  Either sem.
# 59   4 credits.     1st sem.
# 60   4 credits.  Either sem.
# 61   4 credits.
# 62   4 credits.     1st sem.
# 63   4 credits.  Either sem.
# 64   4 credits.  Either sem.
# 65   4 credits.  Either sem.
# 66   4 credits.  Either sem.
# 67   4 credits.  Either sem.
# 68   4 credits.
# 69   4 credits.
# 70   4 credits.  Either sem.
# 71   4 credits.
# 72   4 credits.
# 73   4 credits.
# 74   4 credits.  Either sem.
# 75   4 credits.  Either sem.
# 76   4 credits.  Either sem.
# 77   4 credits.  Either sem.
# 78   4 credits.  Either sem.
# 79   4 credits.
# 80   4 credits.  Either sem.
# 81   4 credits.  Either sem.
# 82   4 credits.     2nd sem.
# 83   4 credits.  Either sem.
# 84   4 credits.
# 85   4 credits.
# 86   4 credits.     2nd sem.
# 87   4 credits.  Either sem.
# 88   4 credits.
# 89   4 credits.
# 90   4 credits.
# 91   4 credits.
# 92   4 credits.
# 93   4 credits.
# 94   4 credits.  Either sem.
# 95   4 credits.
# 96   4 credits.
# 97   4 credits.  Either sem.
# 98   4 credits.
# 99   4 credits.
# 100  0 credits.     2nd sem.
# 101  4 credits.  Either sem.
# 102  4 credits.  Either sem.
# 103  4 credits.     1st sem.
# 104  4 credits.
# 105  4 credits.  Either sem.
# 106  4 credits.     1st sem.
# 107  4 credits.  Either sem.
# 108  4 credits.  Either sem.
# 109  4 credits.  Either sem.
# 110  4 credits.  Either sem.
# 111  4 credits.  Either sem.
# 112  4 credits.  Either sem.
# 113  4 credits.
# 114  4 credits.     2nd sem.
# 115  4 credits.  Either sem.
# 116  4 credits.  Either sem.
# 117  4 credits.  Either sem.
# 118  4 credits.
# 119  4 credits.     2nd sem.
# 120  4 credits.  Either sem.
# 121  4 credits.  Either sem.
# 122  4 credits.  Either sem.
# 123  4 credits.  Either sem.
# 124  4 credits.
# 125  4 credits.  Either sem.
# 126  4 credits.
# 127  4 credits.     2nd sem.
# 128  4 credits.
# 129  4 credits.
# 130  4 credits.
# 131  4 credits.
# 132  4 credits.
# 133  4 credits.
# 134  4 credits.  Either sem.
# 135  4 credits.
# 136  0 credits.  Either sem.
# 137  4 credits.  Either sem.
# 138  4 credits.  Either sem.
# 139  4 credits.  Either sem.
# 140  4 credits.  Either sem.
# 141  4 credits.  Either sem.
# 142  4 credits.  Either sem.
# 143  4 credits.  Either sem.
# 144  4 credits.  Either sem.
# 145  4 credits.
# 146  4 credits.  Either sem.
# 147  4 credits.  Either sem.
# 148  4 credits.
# 149  4 credits.  Either sem.
# 150  2 credits.     2nd sem.
# 151  4 credits.  Either sem.
# 152  4 credits.     2nd sem.
# 153  4 credits.     1st sem.
# 154  4 credits.  Either sem.
# 155  4 credits.  Either sem.
# 156  4 credits.  Either sem.
# 157  4 credits.  Either sem.
# 158  4 credits.  Either sem.
# 159  4 credits.     2nd sem.
# 160  0 credits.
# 161  4 credits.  Either sem.
# 162  4 credits.  Either sem.
# 163  4 credits.  Either sem.
# 164  4 credits.  Either sem.
# 165  4 credits.  Either sem.
# 166  4 credits.
# 167  4 credits.  Either sem.
# 168  4 credits.
# 169  4 credits.  Either sem.
# 170  4 credits.  Either sem.
# 171  4 credits.  Either sem.
# 172  4 credits.  Either sem.
# 173  4 credits.  Either sem.
# 174  4 credits.
# 175  4 credits.  Either sem.
#
#                                                                                                                                                                                                 Prerequisites  \
# 0                                                                                                                                                         First Year Writing Seminar (e.g., WR 100 or WR 120)
# 1                                                         junior or senior standing and at least two previous Sociology courses; or consent of instructor.  First-Year Writing Seminar (WR 120 or equivalent)
# 2
# 3                                                                                                                                                         First Year Writing Seminar (e.g., WR 100 or WR 120)
# 4
# 5
# 6
# 7                                                                                                                                                enrollment in the Madrid Spanish & European Studies Program.
# 8                                                                                                                                                        First Year Writing Seminar (e.g., WR 100 or WR 120).
# 9                                                                                                        CAS AH 111 and CAS AH 112; and two courses at the 200 level or higher, or consent of the instructor.
# 10                                                                                                                                                        First Year Writing Seminar (e.g., WR 100 or WR 120)
# 11
# 12                                                                                                                                                        First Year Writing Seminar (e.g., WR 100 or WR 120)
# 13
# 14
# 15                                                                                                                                            CAS AS 312; First Year Writing Seminar (e.g., WR 100 or WR 120)
# 16                                                                                                CAS BI 107 and CAS BI 108; and First Year Writing Seminar (e.g., WR 100 or WR 120), and sophomore standing.
# 17                                                                                                                                                        First Year Writing Seminar (e.g., WR 100 or WR 120)
# 18                                                                                                                                                          First-Year Writing Seminar (WR 120 or equivalent)
# 19                                                                                                                                                    First Year Writing Seminar (e.g. CAS CC 102 or WR 120).
# 20
# 21                                                                                                                                                                                                CAS CH 211.
# 22                                                                                                                                                          First-Year Writing Seminar (WR 120 or equivalent)
# 23                                                                                                                                                        First Year Writing Seminar (e.g., WR 100 or WR 120)
# 24
# 25
# 26                                                                                                                                                      First-year writing seminar (e.g., CAS WR 100 or 120).
# 27                                                                                                                                                        First Year Writing Seminar (e.g., WR 100 or WR 120)
# 28
# 29                                                                                                     CAS CL 102 or CAS CL 222; First Year Writing Seminar (e.g., WR 100 or WR 120) or consent of instructor
# 30                                                                                                                                                    First Year Writing Seminar (e.g., CAS WR 100 or WR 120)
# 31                                                                                                                                                                                 First-Year Writing Seminar
# 32                                                                                                                                                        First Year Writing Seminar (e.g., WR 100 or WR 120)
# 33                                                                                      two courses in classical civilization, or consent  of instructor. First Year Writing Seminar (e.g., WR 100 or WR 120)
# 34
# 35
# 36                                                                                                                                                        First Year Writing Seminar (e.g., WR 100 or WR 120)
# 37                                                                                                                                             First Year Writing Seminar (e.g., EN 120 or WR 100 or WR 120).
# 38                                                                                                                                                        First Year Writing Seminar (e.g., WR 100 or WR 120)
# 39                                                                                                                                               one previous literature course or junior or senior standing.
# 40                                                                                                                                               one previous literature course or junior or senior standing.
# 41                                                                                                                                                       First Year Writing Seminar (e.g., WR 100 or WR 120).
# 42                                                                                                                                                        First Year Writing Seminar (e.g., WR 100 or WR 120)
# 43
# 44   Consent of instructor, on the basis of a writing sample. 10 poems should be submitted to crwr@bu.edu by 12/15/23; this submission should note whether or not the applicant has taken EN 202 and/or EN 30
# 45                                                                                                                                                Two previous literature courses or junior or senior status.
# 46                                                                                                                                              two previous literature courses or junior or senior standing.
# 47                         consent of instructor, to whom a short play or scene from a play mustbe submitted during the period just before classes begin. First Year Writing Seminar (e.g., WR 100 or WR 120)
# 48                    First-Year Writing Seminar (e.g., WR 100 or 120) and by consent of instructor, to whom a short play or scene from a play must be submitted during the period just before classes begin.
# 49                                    CAS WR 100 or WR 120 along with the consent of the instructor, to whom a short play or scene from a play must be submitted during the period just before classes begin.
# 50                         consent of instructor, to whom a short play or scene from a play mustbe submitted during the period just before classes begin. First Year Writing Seminar (e.g., WR 100 or WR 120)
# 51                                                                                               two previous literature courses or junior or senior standing; and First-Year Writing (WR 120 or equivalent).
# 52                                                                                               two previous literature courses or junior or senior standing; and First-Year Writing (WR 120 or equivalent).
# 53
# 54                                                                                                                         junior standing or consent of instructor. First-Year Writing Seminar (e.g., WR120)
# 55                                                                                                                                                        First Year Writing Seminar (e.g., WR 100 or WR 120)
# 56
# ...
# 169                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Other faces, frames, transformations and disguises, masks speak to what it  is    to be human among other humans, unifying the body and the psyche in ways  few    objects do. Participants study the complexity of masks as a cross- disciplinary    nexus.  Effective Spring 2021 this course fulfills a single  unit in each of the    following BU Hub areas: Global Citizenship and  Intercultural Literacy,    Aesthetic Exploration, Creativity/Innovation.
# 170                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Why do contemporary writers parrot and parody "Shakespeare," and how much of       this activity is about Shakespeare at all? This seminar provides an       introduction to reading and writing about Shakespeare's plays. But it also       takes a step back to consider Shakespeare as a phenomenon. Among others  we'll      look at feminist Shakespeare, postcolonial and nationalist  Shakespeare, and      sci-fi Shakespeare. Beyond learning about particular  offshoots and adaptations,      the deeper point is to make sure you never  read a "Great Book" the same way      again. Effective Fall 2018, this course  fulfills a single unit in each of the    following BU Hub areas: Aesthetic  Exploration, Global Citizenship and    Intercultural Literacy,   Creativity/Innovation.
# 171                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Persuasive written and oral communications are essential skills that are  required for success in  every business discipline. In this course, students  will learn how to communicate clearly and  persuasively. Course objectives  include learning how to inspire action through compelling, high- impact  communications by taking a point of view and supporting it with logic and  evidence,  generating insights with meaningful conclusions and recommendations,  and understanding and  applying the principles of logical reasoning to organize  information and lead an audience to  action. Effective Fall 2018, this course  fulfills a single unit in each of the following BU Hub areas: Writing,  Research,  and Inquiry, Oral and/or Signed Communication, Research and  Information Literacy.
# 172                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Provides students with a powerful set of tools which will prepare them to  analyze, formulate, and  implement business firm strategy with the aim of  attaining sustainable competitive advantage.  Adopts the perspective of the  general manager, challenging student knowledge in each functional  area in the  effort to create integrative strategies that serve the needs of shareholders,  as well  as other stakeholders inside and outside the company. The course  includes conceptual readings,  which elucidate the fundamental concepts and  frameworks of strategic management, as well as case  analyses. Effective Fall 2018, this  course fulfills a single unit in each of the following BU Hub  areas: Global  Citizenship and Intercultural Literacy, Writing-Intensive Course,   Creativity/Innovation.
# 173                                                                                                                                                                                                                                              Persuasive written and oral communications are essential skills that are   required for success in every business discipline. In this course, students   will learn how to communicate clearly and persuasively. Course objectives   include learning how to inspire action through compelling, high-impact   communications by taking a point of view and supporting it with logic and   evidence, generating insights with meaningful conclusions and  recommendations,  and understanding and applying the principles of logical  reasoning to organize  information and lead an audience to action. Students  will learn to write simply  and clearly in a variety of formats. They will  also master presentation  delivery by connecting authentically to the  audience, harnessing the power of  storytelling, and using body language to  positively reinforce the message.  Finally, students will enhance  professional skills that are integral to  business success. Effective Fall  2020, this course fulfills a single unit in each of the following BU Hub  areas: Oral and/or Signed Communication, Research and Information Literacy,  Writing, Research & Inquiry.
# 174                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            This study abroad course introduces students to the Mediterranean lifestyle     and its relationship to health promotion/disease prevention. Students are     exposed to Italian food culture, agriculture, food industry and the     scientific evidence demonstrating the health benefits of the Mediterranean     diet. Effective Summer 2020, this course fulfills a single unit in each of   the   following BU Hub areas: The Individual in Community, Global   Citizenship and   Intercultural Literacy, Creativity/Innovation.
# 175                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   This exploratory course introduces students to a critical history of schooling  in America and the extent to which various philosophies of education can work  (and have worked) in service of or in opposition to democratic and justice- oriented ends. Students will begin to cultivate a critically reflective stance  toward classroom experiences, educational policies, their identities, and the  intersection among them. This course requires 4 hours of field-based experience.  Effective Fall 2022, this course fulfills a single unit in each of the following  BU Hub areas: Writing-Intensive Course, The Individual in Community,  Philosophical Inquiry and Life's Meanings.
#
#                          Hubs
# 0                AEX RIL WIN
# 1                GCI RIL WIN
# 2                AEX GCI RIL
# 3                IIC RIL WIN
# 4                AEX GCI RIL
# 5                AEX GCI RIL
# 6                AEX GCI RIL
# 7                AEX GCI CRI
# 8                AEX GCI WIN
# 9                AEX OSC RIL
# 10               OSC RIL WIN
# 11               AEX IIC CRI
# 12               AEX GCI WIN
# 13               IIC GCI RIL
# 14               OSC RIL WIN
# 15               OSC RIL WIN
# 16               PLM OSC WIN
# 17               OSC RIL WIN
# 18               GCI OSC WIN
# 19               AEX WRI RIL
# 20               AEX GCI RIL
# 21           SI2 OSC RIL CRI
# 22               AEX GCI WIN
# 23               AEX GCI WIN
# 24               AEX GCI RIL
# 25               AEX GCI CRI
# 26               PLM RIL WIN
# 27               AEX RIL WIN
# 28               PLM GCI CRI
# 29               AEX RIL WIN
# 30               AEX RIL WIN
# 31               AEX CRI WIN
# 32               OSC CRI WIN
# 33               OSC RIL WIN
# 34               AEX GCI RIL
# 35               PLM AEX CRI
# 36               OSC CRI WIN
# 37               WRI OSC RIL
# 38               AEX CRI WIN
# 39               AEX IIC CRI
# 40               AEX GCI CRI
# 41               AEX OSC WIN
# 42               AEX CRI WIN
# 43               AEX GCI CRI
# 44               AEX CRI WIN
# 45               AEX GCI RIL
# 46               PLM AEX CRI
# 47               AEX CRI WIN
# 48               AEX CRI WIN
# 49               AEX CRI WIN
# 50               AEX CRI WIN
# 51               AEX RIL WIN
# 52               PLM RIL WIN
# 53               IIC GCI RIL
# 54               GCI OSC WIN
# 55               OSC RIL WIN
# 56               AEX GCI CRI
# 57               GCI OSC CRI
# 58               AEX GCI WIN
# 59               PLM GCI WIN
# 60               AEX GCI WIN
# 61               PLM GCI CRI
# 62               AEX OSC CRI
# 63               AEX GCI WIN
# 64               GCI OSC WIN
# 65               AEX GCI CRI
# 66               AEX GCI WIN
# 67               AEX GCI WIN
# 68               AEX IIC CRI
# 69               AEX GCI WIN
# 70               AEX GCI CRI
# 71               AEX GCI WIN
# 72               PLM RIL WIN
# 73               GCI OSC CRI
# 74               AEX GCI WIN
# 75               AEX GCI CRI
# 76               AEX GCI WIN
# 77               GCI OSC CRI
# 78               GCI OSC WIN
# 79               GCI OSC WIN
# 80               AEX GCI WIN
# 81               AEX GCI WIN
# 82               PLM GCI CRI
# 83               AEX CRI WIN
# 84               AEX OSC WIN
# 85               AEX GCI CRI
# 86               PLM GCI CRI
# 87               AEX GCI WIN
# 88               AEX GCI WIN
# 89               IIC GCI WIN
# 90               GCI OSC CRI
# 91               AEX GCI WIN
# 92               AEX GCI RIL
# 93               AEX GCI WIN
# 94               AEX GCI RIL
# 95               GCI RIL WIN
# 96               AEX GCI WIN
# 97               GCI OSC CRI
# 98               AEX GCI WIN
# 99               AEX GCI WIN
# 100  SO1 IIC GCI ETR OSC TWC
# 101              PLM GCI WIN
# 102              PLM OSC WIN
# 103              PLM GCI WIN
# 104              PLM GCI WIN
# 105              IIC RIL WIN
# 106              IIC RIL WIN
# 107              OSC RIL WIN
# 108              OSC RIL WIN
# 109              PLM GCI CRI
# 110              AEX GCI CRI
# 111              PLM GCI CRI
# 112              PLM GCI WIN
# 113              PLM GCI WIN
# 114              AEX GCI WIN
# 115              IIC RIL WIN
# 116              PLM GCI WIN
# 117              GCI RIL WIN
# 118              GCI RIL WIN
# 119              IIC GCI CRI
# 120              WRI OSC RIL
# 121              WRI RIL CRI
# 122              IIC CRI WIN
# 123              AEX GCI WIN
# 124              AEX GCI WIN
# 125              AEX GCI WIN
# 126              AEX GCI WIN
# 127              PLM GCI CRI
# 128              OSC CRI WIN
# 129              AEX GCI WIN
# 130              AEX GCI WIN
# 131              AEX GCI CRI
# 132              AEX CRI WIN
# 133              AEX GCI WIN
# 134              AEX GCI WIN
# 135              OSC RIL WIN
# 136              IIC GCI CRI
# 137              AEX IIC CRI
# 138              AEX OSC CRI
# 139              IIC GCI CRI
# 140              AEX OSC CRI
# 141              RIL CRI WIN
# 142              AEX OSC CRI
# 143              AEX GCI CRI
# 144              AEX OSC CRI
# 145              IIC CRI WIN
# 146              IIC GCI RIL
# 147              AEX GCI RIL
# 148              AEX CRI WIN
# 149              AEX GCI RIL
# 150              GCI OSC WIN
# 151              PLM AEX CRI
# 152              WRI OSC RIL
# 153              GCI RIL WIN
# 154              OSC RIL WIN
# 155              IIC RIL WIN
# 156              IIC OSC CRI
# 157              GCI OSC CRI
# 158          OSC DME RIL WIN
# 159          OSC DME RIL WIN
# 160              IIC GCI OSC
# 161          RIL TWC CRI WIN
# 162          OSC RIL TWC CRI
# 163          OSC RIL TWC CRI
# 164              PLM AEX CRI
# 165              AEX IIC CRI
# 166              AEX RIL CRI
# 167              AEX CRI WIN
# 168              AEX OSC CRI
# 169              AEX GCI CRI
# 170              AEX GCI CRI
# 171              WRI OSC RIL
# 172              GCI CRI WIN
# 173              WRI OSC RIL
# 174              IIC GCI CRI
# 175              PLM IIC WIN
